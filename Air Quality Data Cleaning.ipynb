# %%
import pandas as pd

# %%
path = "/content/air quality original.csv" # 🔹 change this to your file path
df = pd.read_csv(path)
print("Original Data:\n", df.head())
df = df.drop_duplicates()
df = df.dropna(how='all')
df = df.replace(r'^\s*$', pd.NA, regex=True)
for col in df.select_dtypes(include=['object']).columns:
    try:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    except:
        pass  # skip non-numeric columns safely
for col in df.columns:
    if df[col].dtype == 'float64' or df[col].dtype == 'int64':
        # numeric columns → use mean
        df[col] = df[col].fillna(df[col].mean())
    else:
        # categorical/text columns → use mode
        df[col] = df[col].fillna(df[col].mode()[0])
print("\nCleaned Data:\n")
# Save cleaned dataset (optional)
df.to_csv("cleaned_dataset.csv", index=False)
print("\n✅ Cleaned dataset saved as 'cleaned_dataset.csv'")
# Out:
# /tmp/ipython-input-2665521629.py:2: DtypeWarning: Columns (2,5,6,7,8,9,10,11,12,13,16,17,18,19,20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# Original Data:
#      sitename          county aqi pollutant    status  so2    co    o3 o3_8hr  \
# 0      Hukou  Hsinchu County  62     PM2.5  Moderate  0.9  0.17    35   40.2
# 1  Zhongming   Taichung City  50       NaN      Good  1.6  0.32  27.9   35.1
# 2    Zhudong  Hsinchu County  45       NaN      Good  0.4  0.17  25.1   40.6
# 3    Hsinchu    Hsinchu City  42       NaN      Good  0.8   0.2    30   35.9
# 4     Toufen   Miaoli County  50       NaN      Good    1  0.16  33.5   35.9
#
#   pm10  ...   no windspeed winddirec co_8hr pm2.5_avg pm10_avg so2_avg  \
# 0   18  ...  0.3       2.3       225    0.2      20.1       26       1
# 1   27  ...  1.6       1.1       184    0.2      15.3       23       1
# 2   21  ...  1.1       0.4       210    0.2      13.8       24       0
# 3   19  ...  0.7       1.9       239    0.2        13       26       1
# 4   18  ...  1.2       1.8       259    0.1      15.3       28       1
#
#      longitude     latitude siteid
# 0  121.0388689  24.90009696     22
# 1   120.641092    24.151958     31
# 2  121.0889549  24.74091408     23
# 3  120.9723675   24.8056356     24
# 4  120.8986929  24.69690679     25
#
# [5 rows x 23 columns]
#
# Cleaned Data:
#
#
# ✅ Cleaned dataset saved as 'cleaned_dataset.csv'
